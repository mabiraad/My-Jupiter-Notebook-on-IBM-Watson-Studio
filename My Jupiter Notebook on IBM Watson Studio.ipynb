# %% [markdown]
# # My Jupiter Notebook on IBM Watson Studio

# %% [markdown]
# **Maria Abi Raad**
#
# Data Analyst

# %% [markdown]
# <i>I am interested in Data Science because I beleive in the power of Data and its ability to prevent and prepare for uncertain futures.

# %% [markdown]
# ### The Following code calculates the arythmetics sum of the Numbers 1 and 4.

# %%
print(1+4)
# Out:
# 5

# %% [markdown]
# So far in this Notebook, we have tried to demonstrate cells containing:
# 1. A title in H1 Header styling
# 2. Two tasks
# * A name in bold
# * A current or desired occupation in regular font
# 3. A description of the interest in data science.
# 4. A little explanation on the main role of the cell 5's code.
#
#
# ***
#
# Now we shall move on with a demonstration of recapitulation table
#
#
#
# |Task|Time needed to complete the task|Difficulty|
# |-----|-------|------|
# |1|2 minutes|Easy|
# |2|1 minute|Easy|
# |3|2 minutes|Easy|
# |4|2 minute|Medium|
#
#  ***
#
# For more information about IBM and Data Analytics, make sure to check out [www.ibm.com](https://www.ibm.com/fr-fr)
